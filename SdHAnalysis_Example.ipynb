# %% [markdown]
# # SdH Analysis
# ----------------------------
# ### Example of the analysis of Shubnikov-de Haas data measured using TDO in pulsed fields.

# %%
from sdhanalysis import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sweep1 = SdHDataSet('Example name', 'Example date')

# %%
sweep1.load_data(15,5)

# %%
sweep1.subtract_background(5, 10, 40, save=True)

# %%
sweep1.get_fft_peaks(mph=1.3e6, mpd=10, threshold=2, xmax=400, keep_ind=[2,4,5,6,8], save=True)
# Out:
# The following 5 peaks have been added to the dataset:
#
#             Amp         Freq  Ind
# 0  4.610175e+07   593.844126   44
# 1  5.623792e+06  1187.688252   88
# 2  7.053867e+06  3252.646235  241
# 3  1.111564e+07  3846.490361  285
# 4  2.030629e+06  4453.830944  330

# %%
center_freq, passband, orbit = 594, 100, '594 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 594 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 1188, 100, '1188 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 1188 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 3253, 100, '3253 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 3253 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 3846, 100, '3846 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 3846 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 4454, 100, '4454 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 4454 T orbit has been added to the dataset.

# %%
sweep1.get_peak_amplitudes('594 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 594 T.

# %%
sweep1.get_peak_amplitudes('1188 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 1188 T.

# %%
sweep1.get_peak_amplitudes('3253 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 3253 T.

# %%
sweep1.get_peak_amplitudes('3846 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 3846 T.

# %%
sweep1.get_peak_amplitudes('4454 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 4454 T.

# %%
sweep1.plot_orbit_amplitudes()
