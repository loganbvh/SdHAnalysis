# %% [markdown]
# # SdH Analysis
# ----------------------------
# ### Example of the analysis of Shubnikov-de Haas data measured using TDO in pulsed fields.

# %%
from sdhanalysis import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sweep1 = SdHDataSet('Example name', 'Example date')

# %%
sweep1.load_data(15,5)

# %%
sweep1.subtract_background(5, 1, 4, save=True)

# %%
sweep1.get_fft_peaks(mph=1.3e6, mpd=10, threshold=2, xmax=400, keep_ind=[2,4,5,6,8], save=True)
# Out:
# The following 5 peaks have been added to the dataset:
#
#             Amp        Freq  Ind
# 0  4.610175e+07   59.384413   44
# 1  5.623792e+06  118.768825   88
# 2  7.053867e+06  325.264623  241
# 3  1.111564e+07  384.649036  285
# 4  2.030629e+06  445.383094  330

# %%
center_freq, passband, orbit = 60, 10, '60 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 60 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 118, 10, '118 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 118 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 324, 10, '324 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 324 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 384, 10, '384 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 384 T orbit has been added to the dataset.

# %%
center_freq, passband, orbit = 446, 10, '446 T'
sweep1.isolate_orbit(orbit, center_freq, passband, save=True)
# Out:
# The filtered 446 T orbit has been added to the dataset.

# %%
sweep1.get_peak_amplitudes('60 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 60 T.

# %%
sweep1.get_peak_amplitudes('118 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 118 T.

# %%
sweep1.get_peak_amplitudes('324 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 324 T.

# %%
sweep1.get_peak_amplitudes('384 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 384 T.

# %%
sweep1.get_peak_amplitudes('446 T', save=True)
# Out:
# The below peaks have been added to the dataset under orbit 446 T.

# %%
sweep1.plot_orbit_amplitudes()
